# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
runtimes_logalphaCE = np.array([25228, 30046, 85823])
runtimes = np.array([35633,29319,81457])
runtimes_ave = np.mean([runtimes_logalphaCE, runtimes], axis=0)
prop = [runtimes_logalphaCE[0], runtimes_logalphaCE[0]*2, runtimes_logalphaCE[0]*5]
no_events = [50,100,250]

# %%
plt.plot(no_events, runtimes_logalphaCE)
plt.plot(no_events, runtimes)
plt.plot(no_events, runtimes_ave)
plt.plot(no_events, prop)
